# %%
# !git clone https://github.com/vandat2614/NoOneMore.git
# Out:
# Cloning into 'NoOneMore'...
# remote: Enumerating objects: 10, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 10 (delta 1), reused 9 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (10/10), 23.76 MiB | 18.96 MiB/s, done.
# Resolving deltas: 100% (1/1), done.

# %%
cd /kaggle/working/NoOneMore
# Out:
# /kaggle/working/NoOneMore

# %%
# pip install -r requirements.txt
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 3.4 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.4 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 35.3 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 32.0 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 41.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.2 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 7.3 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 22.5 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 10.8 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 7.2 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 34.3 MB/s eta 0:00:0000:0100:01
# ...

# %%
from ultralytics import YOLO

# %%
model = YOLO(model="yolov8x") # largest model, auto download weight if not exists

# %%
results = model.predict(source='input_videos/B1606b0e6_1.mp4', # can be image or video (images)
                        save=True)
# Out:
# WARNING ⚠️
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/750) /kaggle/working/NoOneMore/input_videos/B1606b0e6_1.mp4: 384x640 22 persons, 51.2ms
# video 1/1 (frame 2/750) /kaggle/working/NoOneMore/input_videos/B1606b0e6_1.mp4: 384x640 21 persons, 27.2ms
# video 1/1 (frame 3/750) /kaggle/working/NoOneMore/input_videos/B1606b0e6_1.mp4: 384x640 22 persons, 26.7ms
# video 1/1 (frame 4/750) /kaggle/working/NoOneMore/input_videos/B1606b0e6_1.mp4: 384x640 22 persons, 27.1ms
# ...

# %%
len(results) # 750 frame in video
# Out:
# 750

# %%
# each frame result include [boxes, keypoints, mask, names {id : name}, obb, orig_img, orig_shape, path (soucre), probs, save_dir, speed]

results[0]
# Out:
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# ...

# %%
len(results[0].boxes) # in first frame, have 22 object
# Out:
# 22

# %%
# each bounding box include [cls, conf, data (bb - xyxy + conf + cls), id, is_track, orig_shape, shape, xywh, xywhn, xyxy, xyxyn]
 # n may be normalize coordinate to percent of image

results[0].boxes[0]
# Out:
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.], device='cuda:0')
# conf: tensor([0.8650], device='cuda:0')
# data: tensor([[1.4657e+03, 3.9505e+02, 1.5006e+03, 4.7348e+02, 8.6499e-01, 0.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[1483.1730,  434.2657,   34.9260,   78.4338]], device='cuda:0')
# xywhn: tensor([[0.7725, 0.4021, 0.0182, 0.0726]], device='cuda:0')
# xyxy: tensor([[1465.7100,  395.0489, 1500.6360,  473.4826]], device='cuda:0')
# xyxyn: tensor([[0.7634, 0.3658, 0.7816, 0.4384]], device='cuda:0')
